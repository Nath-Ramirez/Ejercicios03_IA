# %% [markdown]
# # 🚕 Q-Learning en Taxi-v4 — Trabajo en casa
#
# En este ejercicio aplicará Q-Learning al ambiente **Taxi-v4** de Gymnasium.
#
# La lógica es la misma trabajada en FrozenLake:
#
# $$
# (s_t,a_t) \rightarrow (r_{t+1},s_{t+1})
# $$
#
# y la actualización:
#
# $$
# Q(s_t,a_t)
# \leftarrow
# Q(s_t,a_t)
# +
# \alpha
# \left[
# r_{t+1}
# +
# \gamma \max_a Q(s_{t+1},a)
# -
# Q(s_t,a_t)
# \right]
# $$
#
# ## Objetivo
#
# Implementar y analizar un agente Q-Learning capaz de aprender a recoger un pasajero y llevarlo a su destino.

# %% [markdown]
# ## 1. Preparación
#
# Instale Gymnasium si es necesario:
#
# ```bash
# pip install gymnasium[toy-text]
# ```

# %%
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt

from IPython.display import HTML
from matplotlib import animation

# %% [markdown]
# ## 2. Crear el ambiente
#
# Taxi tiene un número de estados mucho mayor que FrozenLake.
#
# Cada estado codifica:
#
# - posición del taxi,
# - ubicación del pasajero,
# - destino del pasajero.
#
# Las acciones posibles son:
#
# | Acción | Significado |
# |---|---|
# | 0 | South |
# | 1 | North |
# | 2 | East |
# | 3 | West |
# | 4 | Pickup |
# | 5 | Dropoff |

# %%
env = gym.make("Taxi-v4", render_mode="rgb_array")

print("Número de estados:", env.observation_space.n)
print("Número de acciones:", env.action_space.n)

# %% [markdown]
# ### Pregunta 1
#
# ¿Cuántos estados y cuántas acciones tiene Taxi-v4?
#
# Explique brevemente por qué Taxi tiene muchos más estados que FrozenLake.
#
# = Taxi-v4 contiene 500 estados y 6 acciones, tiene muchos más estados que FrozenLake (que solo tiene 16). La razón de esto es porque en FrozenLake un estado es representado únicamente por la casilla en que se encuentra el jugador:
#
# *   Si tenemos un FrozenLake de 4 x 4, entonces hay 16 casillas, y por lo tanto 16 estados
#
# Por otro lado, el taxi-v4 es representado por:
#
# *   La posición del taxi: hay 25 posiciones disponibles
# *   Posición del pasajero: hay 5 posibilidades (4 donde puede esperar y uno de llegada)
# *   Destino: hay 4 posibilidades
#
# Entonces: 25 x 5 x 4 = 500

# %% [markdown]
# ## 3. Observar una interacción
#
# Ejecute una acción aleatoria y observe qué devuelve el ambiente.

# %%
state, info = env.reset(seed=42)

action = env.action_space.sample()

next_state, reward, terminated, truncated, info = env.step(action)

print("Estado:", state)
print("Acción:", action)
print("Nuevo estado:", next_state)
print("Recompensa:", reward)
print("Terminated:", terminated)

# %% [markdown]
# ### Pregunta 2
#
# En la interacción anterior identifique:
#
# $$
# s_t,\quad a_t,\quad r_{t+1},\quad s_{t+1}
# $$
#
# ¿Qué representa cada elemento?
#
# *  $ s_t = 368 $ -> Representa el estado actual
# *  $ \quad a_t = 2 $ -> Representa la acción que realiza el agente
# *  $ \quad r_{t+1} = -1 $ -> Representa la recompensa obtenida después de realizar la acción
# *  $ \quad s_{t+1} = 386 $ -> Representa el nuevo estado después de realizar la acción

# %% [markdown]
# ## 4. Inicializar la Q-table
#
# Cada fila corresponde a un estado y cada columna a una acción.
#
# Inicialmente:
#
# $$
# Q(s,a)=0
# $$

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n

Q = np.zeros((n_states, n_actions))

print("Shape de Q:", Q.shape)
Q[:5]

# %% [markdown]
# ### Pregunta 3
#
# ¿Cuántos valores debe aprender el agente en total?
#
# Calcule:
#
# $$
# |\mathcal{S}| \times |\mathcal{A}|
# $$
#
# Cómo tenemos 500 states y 6 actions, entonces:
#
# $$ 500 \times 6 = 3000 $$
#
# El agente de aprender 3000 valores Q en total, quedando de la forma $ \mathcal{Q}(s,a) $ que significa:
#
# ¿Que tan conveniente es realizar la acción $a$ si estoy en el estado $s$?

# %% [markdown]
# ## 5. Política $\epsilon$-greedy
#
# Implemente una función que:
#
# - con probabilidad $\epsilon$ seleccione una acción aleatoria;
# - en otro caso seleccione:
#
# $$
# \arg\max_a Q(s,a)
# $$
#
# ### Actividad 1
# Complete la función.

# %%
def choose_action(Q, state, epsilon, env):
    # Decidir si explorar o explotar
    if np.random.rand() < epsilon:
        # Explorar: elegir una acción aleatoria
        return env.action_space.sample()    # selecciona una acción aleatoria entre las 6 disponibles
    else:
        # Explotar: elegir la acción con mayor valor Q
        return np.argmax(Q[state])

# %% [markdown]
# ## 6. Actualización de Q
#
# La regla de actualización es:
#
# $$
# Q(s,a)
# \leftarrow
# Q(s,a)
# +
# \alpha
# \left[
# r+
# \gamma\max_{a'}Q(s',a')
# -
# Q(s,a)
# \right]
# $$
#
# ### Actividad 2
# Complete la función.

# %%
def update_q(Q, state, action, reward, next_state, alpha, gamma):
    # Calcular el target
    target = reward + gamma * np.max(Q[next_state])

    # Calcular el error TD
    td_error = target - Q[state, action]

    # Actualizar Q[state, action]
    Q[state, action] += alpha * td_error

# %% [markdown]
# ## 7. Entrenamiento
#
# Ahora implemente el ciclo completo de Q-Learning.
#
# En cada episodio:
#
# 1. reiniciar el ambiente;
# 2. escoger una acción;
# 3. ejecutar `env.step(action)`;
# 4. actualizar $Q(s,a)$;
# 5. mover el agente a `next_state`;
# 6. terminar cuando el episodio finalice.
#
# Use inicialmente:
#
# ```python
# alpha = 0.1
# gamma = 0.95
# epsilon = 0.1
# episodes = 5000
# ```
#
# ### Actividad 3
# Complete la función.

# %%
def train_q_learning(
    env,
    Q,
    episodes=5000,
    alpha=0.1,
    gamma=0.95,
    epsilon=0.1,
    max_steps=200
):
    rewards = []

    for episode in range(episodes):
        state, _ = env.reset()
        total_reward = 0

        for _ in range(max_steps):

            # TODO 1: escoger acción
            action = choose_action(Q, state, epsilon, env)

            # TODO 2: ejecutar acción en el ambiente
            next_state, reward, terminated, truncated, _ = env.step(action)

            # TODO 3: actualizar Q
            update_q(Q, state, action, reward, next_state, alpha, gamma)

            # TODO 4: actualizar estado y recompensa acumulada
            state = next_state
            total_reward += reward

            # TODO 5: terminar si corresponde
            if terminated or truncated:
                break

        rewards.append(total_reward)

    return Q, rewards

# %% [markdown]
# ## 8. Entrenar el agente
#
# Ejecute el entrenamiento una vez haya completado las funciones anteriores.

# %%
Q_initial = np.zeros((n_states, n_actions))

Q_trained, rewards = train_q_learning(
    env,
    Q_initial.copy(),
    episodes=5000,
    alpha=0.1,
    gamma=0.95,
    epsilon=0.5
)

# %% [markdown]
# ## 9. Curva de aprendizaje
#
# Observe cómo cambia la recompensa durante el entrenamiento.

# %%
window = 100

moving_average = np.convolve(
    rewards,
    np.ones(window) / window,
    mode="valid"
)

plt.figure(figsize=(10, 4))
plt.plot(moving_average)
plt.xlabel("Episodio")
plt.ylabel("Recompensa promedio")
plt.title(f"Taxi-v3 — recompensa promedio ({window} episodios)")
plt.show()

# %% [markdown]
# ### Pregunta 4
#
# Describa la curva de aprendizaje.
#
# - ¿La recompensa promedio mejora?
#
#     = Si, la curva comienza con valores de recompensa negativos y luego va mejorando progresivamente a medida que el agente aprende.
#
# - ¿Después de aproximadamente cuántos episodios comienza a estabilizarse?
#
#     = La recompenza promedio comienza a estabilizarse aproximadamente después de 1.000 o 1.100 episodios
#
# - ¿El comportamiento observado indica convergencia perfecta o solamente una política razonablemente buena?
#
#     = Esto no demuestra que la convergencia sea perfecta, la recompensa estable solo nos indica que el comportamiento promedio dejó de mejorar significativamente. No demuestra que todos los estados hayan aprendido el valor óptimo, sino que el agente probablemente ha aprendido una política razonablemente buena

# %% [markdown]
# ## 10. Reproducir un episodio
#
# La siguiente función ejecuta una política greedy usando la Q-table aprendida y guarda los frames del episodio.

# %%
def play_episode(env, Q, max_steps=200, seed=None):
    state, _ = env.reset(seed=seed)

    frames = [env.render()]
    total_reward = 0

    for _ in range(max_steps):

        q_values = Q[state]
        max_q = np.max(q_values)

        best_actions = np.flatnonzero(q_values == max_q)
        action = int(np.random.choice(best_actions))

        next_state, reward, terminated, truncated, _ = env.step(action)

        frames.append(env.render())

        total_reward += reward
        state = next_state

        if terminated or truncated:
            break

    return frames, total_reward


def frames_to_video(frames, interval=500):
    fig = plt.figure(figsize=(6, 4))
    plt.axis("off")

    image = plt.imshow(frames[0])

    def update(frame):
        image.set_data(frame)
        return [image]

    anim = animation.FuncAnimation(
        fig,
        update,
        frames=frames,
        interval=interval,
        blit=True,
        repeat=True
    )

    plt.close(fig)
    return HTML(anim.to_jshtml())

# %% [markdown]
# ## 11. Comparar antes y después
#
# Primero observe un Taxi sin entrenamiento usando una Q-table en cero.

# %%
frames_initial, reward_initial = play_episode(
    env,
    Q_initial,
    max_steps=50,
    seed=7
)

print("Recompensa total sin entrenamiento:", reward_initial)
frames_to_video(frames_initial, interval=500)

# %% [markdown]
# Ahora observe el agente entrenado.

# %%
frames_trained, reward_trained = play_episode(
    env,
    Q_trained,
    max_steps=200,
    seed=7
)

print("Recompensa total después del entrenamiento:", reward_trained)
frames_to_video(frames_trained, interval=500)

# %% [markdown]
# ### Pregunta 5
#
# Compare los dos episodios.
#
# - ¿Qué diferencias observa en el comportamiento del taxi?
#
#     = Con la Q_initial el taxi no sabe que acción elegir porque apenas está explorando la recompensa que obtiene de sus acciones y el estado donde está, vemos que el taxi incluso intenta varias veces una misma acción y se queda estancado en muchos lugares, todo esto que observamos es el proceso de aprendizaje del agente.
#
#     Por otro lado, con la Q_trained, el agente va directo donde debe ir, ya sabe que acciones debe tomar porque ya cada Q(s,a) tiene una política razonablemnte buena que lo lleva por el mejor camino, ya no se queda dando vueltas porque ya no nos interesa explorar otros estados, ya todo lo aprendió y ya todo está definido.
#
# - ¿El taxi sin entrenamiento logra completar la tarea?
#
#     = El taxi sin entrenamiento no logró completar la tarea, solo estaba explorando y aprendiendo
#
# - ¿El agente entrenado evita acciones innecesarias?
#
#     = Si, porque ya sabe la recompensa de cada acción en cada estado
#
# - ¿Qué evidencia visual le permite afirmar que el agente aprendió?
#
#     = El agente no explora más estados para encontrar otros caminos, el taxi va directo a donde debe ir guiado por la Q_trained

# %% [markdown]
# ## 12. Analizar la política aprendida
#
# Seleccione un estado cualquiera y observe los valores aprendidos para sus seis acciones.

# %%
state = 123

print("Estado:", state)
print("Q-values:", Q_trained[state])
print("Mejor acción:", np.argmax(Q_trained[state]))

# %% [markdown]
# ### Pregunta 6
#
# Para el estado seleccionado:
#
# 1. ¿Cuál es la acción con mayor valor Q?
#
#     = La mayor acción con mayor valor Q está en la posición 3, la cual es 3.94947757
#
# 2. ¿Qué significa que una acción tenga un valor Q mayor que otra?
#
#     = Significa que, según lo que el agente ha aprendido, esa acción es más conveniente en ese estado porque se espera que produzca una mayor recompensa acumulada en el futuro
#
# 3. ¿Por qué no podemos interpretar $Q(s,a)$ únicamente como la recompensa inmediata de ejecutar la acción?
#
#     = Porque $Q(s,a)$ no representa solamente lo que ganamos inmediatamente, sino el valor esperado de realizar esa acción considerando también las recompensas futuras. La que nos dice la recompensa inmediata es γ

# %% [markdown]
# ## 13. Experimentación
#
# Modifique **solo uno** de los siguientes hiperparámetros y vuelva a entrenar:
#
# - $\alpha$
# - $\gamma$
# - $\epsilon$
#
# ### Pregunta 7
#
# Compare el nuevo entrenamiento con el original.
#
# Explique cómo el cambio del hiperparámetro afectó:
#
# - velocidad de aprendizaje,
# - estabilidad,
# - recompensa final,
# - comportamiento observado.
#
#
# Cambié el hiperparámetro $\epsilon$ de 0.1 a 0.5, permitiendo un 50% de exploración en el entrenamiento.
#
# La velocidad de aprendizaje fue menor, el rendimeinto se estabilizó, según la gráfica, en más episodios de los que tardó en 0.1. Esto es un comportamiento normal porque incluso cuando ya conoce una acción el agente sigue explorando
#
# Tiende a ser menos estable debido a que el agente realiza acciones aleatorias con mayor frecuencia que podrían empeorar el estado actual
#
# La recompensa final, en la parte exploratoria, se reflejó mejor con el $\epsilon$ en 0.1, debido a que con un valor de 0.5 explora más y toma más valores aleatorios que pueden empeorar su rendimiento. Sin embargo, en la recompensa final con el Q_trained, se observa que la recompensa para ambos valores de $\epsilon$ es de 10, por lo tanto, la gran exploración que se realizó con el valor de 0.5 funcionó correctamente
#
# Se observan comportamiento muy diferentes en ambos valores, sobretodo en la fase de entrenamiento:
#
# *  $\epsilon = 0.1$ -> El taxi se observa más consistente, no explora mucho, no intenta muchas acciones
# *  $\epsilon = 0.5$ -> El taxi se observa muy exploratorio, intenta explorar varios estados consiguiendo recompensas de todo tipo, explora más el mapa
#
# Ahora, con Q_trained:
#
# Ambos tienen un comportamiento muy parecido, e incluso comparten la recompensa total. Sin embargo, con $\epsilon = 0.5$ se observa que el taxi sube una posición en el mapa una casilla antes que el $\epsilon = 0.1$, aunque esto finalmente no afecte la recompensa total

# %% [markdown]
# ## Entrega
#
# El notebook debe contener:
#
# 1. implementación de `choose_action`;
# 2. implementación de `update_q`;
# 3. implementación de `train_q_learning`;
# 4. curva de aprendizaje;
# 5. visualización del agente antes y después del entrenamiento;
# 6. respuestas a las siete preguntas.
#
# No es necesario modificar las funciones auxiliares de visualización.
